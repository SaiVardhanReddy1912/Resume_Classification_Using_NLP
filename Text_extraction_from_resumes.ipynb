# %% [markdown]
# ##Resume Classification

# %% [markdown]
# 1. Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from sklearn.naive_bayes import MultinomialNB
from sklearn.multiclass import OneVsRestClassifier
from sklearn import metrics
from sklearn.metrics import accuracy_score
from pandas.plotting import scatter_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -q keras

# %%
# !pip install textract
# Out:
# Requirement already satisfied: textract in /usr/local/lib/python3.10/dist-packages (1.6.5)
# Requirement already satisfied: argcomplete~=1.10.0 in /usr/local/lib/python3.10/dist-packages (from textract) (1.10.3)
# Requirement already satisfied: beautifulsoup4~=4.8.0 in /usr/local/lib/python3.10/dist-packages (from textract) (4.8.2)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.10/dist-packages (from textract) (3.0.4)
# Requirement already satisfied: docx2txt~=0.8 in /usr/local/lib/python3.10/dist-packages (from textract) (0.8)
# Requirement already satisfied: extract-msg<=0.29.* in /usr/local/lib/python3.10/dist-packages (from textract) (0.28.7)
# Requirement already satisfied: pdfminer.six==20191110 in /usr/local/lib/python3.10/dist-packages (from textract) (20191110)
# Requirement already satisfied: python-pptx~=0.6.18 in /usr/local/lib/python3.10/dist-packages (from textract) (0.6.23)
# Requirement already satisfied: six~=1.12.0 in /usr/local/lib/python3.10/dist-packages (from textract) (1.12.0)
# Requirement already satisfied: SpeechRecognition~=3.8.1 in /usr/local/lib/python3.10/dist-packages (from textract) (3.8.1)
# Requirement already satisfied: xlrd~=1.2.0 in /usr/local/lib/python3.10/dist-packages (from textract) (1.2.0)
# Requirement already satisfied: pycryptodome in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20191110->textract) (3.20.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20191110->textract) (2.4.0)
# Requirement already satisfied: soupsieve>=1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4~=4.8.0->textract) (2.5)
# Requirement already satisfied: imapclient==2.1.0 in /usr/local/lib/python3.10/dist-packages (from extract-msg<=0.29.*->textract) (2.1.0)
# Requirement already satisfied: olefile>=0.46 in /usr/local/lib/python3.10/dist-packages (from extract-msg<=0.29.*->textract) (0.47)
# Requirement already satisfied: tzlocal>=2.1 in /usr/local/lib/python3.10/dist-packages (from extract-msg<=0.29.*->textract) (5.2)
# Requirement already satisfied: compressed-rtf>=1.0.6 in /usr/local/lib/python3.10/dist-packages (from extract-msg<=0.29.*->textract) (1.0.6)
# Requirement already satisfied: ebcdic>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from extract-msg<=0.29.*->textract) (1.1.1)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-pptx~=0.6.18->textract) (4.9.4)
# Requirement already satisfied: Pillow>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from python-pptx~=0.6.18->textract) (9.4.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from python-pptx~=0.6.18->textract) (3.2.0)

# %%
# !pip install tensorflow

# %%
import keras

# %%
import textract

# %%
# !apt-get install antiword
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   antiword
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 118 kB of archives.
# After this operation, 603 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 antiword amd64 0.37-16 [118 kB]
# Fetched 118 kB in 1s (234 kB/s)
# Selecting previously unselected package antiword.
# (Reading database ... 121918 files and directories currently installed.)
# Preparing to unpack .../antiword_0.37-16_amd64.deb ...
# Unpacking antiword (0.37-16) ...
# Setting up antiword (0.37-16) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !which antiword
# Out:
# /usr/bin/antiword

# %%
# !pip install docx2txt
# Out:
# Requirement already satisfied: docx2txt in /usr/local/lib/python3.10/dist-packages (0.8)

# %%
import os
import textract

directory = '/content/drive/MyDrive/Resumes_project/Resumes'
file_path1 = []
category1= []

for i in os.listdir(directory):
    if i.endswith('.docx') or i.endswith('.doc') or i.endswith('.pdf'):
        file_path1.append(textract.process(os.path.join(directory, i)))
        category1.append('React developer')

# %%
data1 = pd.DataFrame(data = file_path1 , columns = ['Raw_Details'])
data1['Category1'] = category1
data1
# Out:
#                                           Raw_Details        Category1
# 0   b'MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW...  React developer
# 1   b'Naveen Sadhu\n\n\n\n\n\nTitle: software deve...  React developer
# 2   b'SUSOVAN  BAG   \n\nSeeking  a  challenging  ...  React developer
# 3   b'Name: Ravali P \n\n\n\n                     ...  React developer
# 4   b'Venkatalakshmi Pedireddy\n\nSoftware Develop...  React developer
# 5   b'Kotani Durga Prasad\n\n\n\n\n\nObjective:\n\...  React developer
# 6   b'\n                                        CU...  React developer
# 7   b'Ui-Developer/ React JS Developer \n\nNAME: K...  React developer
# 8   b' \n\n \n\nName: M. Prabakaran \nTitle: UI De...  React developer
# 9   b'Ui-Developer/ React JS Developer \n\nNAME: K...  React developer
# 10  b'\n [pic]\n\nPROFILE\n\n Searching for the op...  React developer
# 11  b'PRAGNYA PATTNAIK\n\n \n\n \n\n \n\n Expertis...  React developer
# 12  b"\nMaryala Vinay Reddy\n\nProfessional Summar...  React developer
# 13  b'MD KHIZARUDDIN RAUF \n\n \t EXPERIENCE \n\n ...  React developer
# 14  b'KAMBALA SAI SURENDRA   \n\n \n\n \n\n \n\n\n...  React developer
# 15  b'SHAIK ABDUL SHARUK   \n\n2 years\xe2\x80\x99...  React developer
# 16  b'Kanumuru Deepak Reddy\n\n\n\n\t\n\n\n\nCAREE...  React developer
# 17  b'Pranish Sonone\n\n\t\t\n\n\n\n\n\n\n\n\n\nCa...  React developer
# 18  b'MAREEDU LOKESH BABU\n\n\n\nPROFESSIONAL OVER...  React developer
# 19  b"Ranga Gaganam  \n\n\n\n \n\nProfessional\n\n...  React developer
# 20  b'KAMALAKAR REDDY. A \n\nLinked In: https://ww...  React developer
# 21  b"SARALA MADASU\n\nSARALA MADASU\n\n\xee\xa5\x...  React developer
# 22  b'HARIPRIYA BATTINA \n\nExperience as UI Devel...  React developer
# 23  b"Thirupathamma Balla\n\n\n\nSUMMARY:\n\n\n\n2...  React developer

# %%
import docx2txt
import textract

directory = '/content/drive/MyDrive/Resumes_project/Resumes/Peoplesoft resumes'### location of the file
file_path2 = []
category2 = []
for i in os.listdir(directory):
    if i.endswith('.docx') or i.endswith('.doc') or i.endswith('.pdf'):
        file_path2.append(textract.process(os.path.join(directory, i)))
        category2.append('PeopleSoft')

# %%
category2
# Out:
# ['PeopleSoft',
#  'PeopleSoft',
#  'PeopleSoft',
#  'PeopleSoft',
#  'PeopleSoft',
#  'PeopleSoft',
#  'PeopleSoft',
#  'PeopleSoft',
#  'PeopleSoft',
#  'PeopleSoft',
#  'PeopleSoft',
#  'PeopleSoft',
#  'PeopleSoft',
#  'PeopleSoft',
#  'PeopleSoft',
#  'PeopleSoft',
#  'PeopleSoft',
#  'PeopleSoft',
#  'PeopleSoft',
#  'PeopleSoft']

# %%
data2 = pd.DataFrame(data = file_path2 , columns = ['Raw_Details'])
data2['Category2'] = category2
data2
# Out:
#                                           Raw_Details   Category2
# 0   b'Priyabrata Hota\n\n\n\n\n\nCAREER OBJECTIVE\...  PeopleSoft
# 1   b'\nVinod Akkala\nPeopleSoft DBA Admin.\n\nPro...  PeopleSoft
# 2   b'Anubhav Kumar Singh\t\t\n\n\n\nCore Competen...  PeopleSoft
# 3   b'PeopleSoft Administration\n\n \n\nVivekanand...  PeopleSoft
# 4   b'\n\nR Ahmed\n      PeopleSoft Technical Cons...  PeopleSoft
# 5   b'\nArun Venu\n\n\n  EXPERIENCE SUMMARY\n\n\n ...  PeopleSoft
# 6   b'\nPriyanka Ramadoss\n\n61/46, MountPleasant,...  PeopleSoft
# 7   b"C O N T A C T :\n\n\n\nAddress: Manyata Tech...  PeopleSoft
# 8   b'\n|Personal Details                         ...  PeopleSoft
# 9   b'Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\...  PeopleSoft
# 10  b'Hari Narayana \t\t              \n\n\t\n\n\n...  PeopleSoft
# 11  b'Tanna Sujatha \n\n\n\n\n\n\n\nOBJECTIVE\n\nS...  PeopleSoft
# 12  b"SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n...  PeopleSoft
# 13  b"\n                                    PEOPLE...  PeopleSoft
# 14  b"PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCar...  PeopleSoft
# 15  b'Classification: Internal\n\nClassification: ...  PeopleSoft
# 16  b"\n                        PeopleSoft Admin/P...  PeopleSoft
# 17  b'\nRahul Ahuja\n-----------------------------...  PeopleSoft
# 18  b'\n                                PeopleSoft...  PeopleSoft
# 19  b'\n\n\n\n\n\n\n\n\nProfile Summary:\n \xe2\x8...  PeopleSoft

# %%
directory = '/content/drive/MyDrive/Resumes_project/Resumes/SQL Developer Lightning insight'
file_path3 = []
category3 = []

for i in os.listdir(directory):
    if i.endswith('.docx') or i.endswith('.doc') or i.endswith('.pdf'):
        file_path3.append(textract.process(os.path.join(directory, i)))
        category3.append('SQL Developer')

# %%
data3 = pd.DataFrame(data = file_path3 , columns = ['Raw_Details'])
data3['Category3'] = category3
data3
# Out:
#                                           Raw_Details      Category3
# 0   b'\n                                       SQL...  SQL Developer
# 1   b'SQL AND MSBI DEVELOPER\n\nSQL AND MSBI DEVEL...  SQL Developer
# 2   b'Name: Ramesh\n\n\t\n\n\tCareer Objective: \n...  SQL Developer
# 3   b"\n\n\n\n\n \xe2\x80\x9c Hyderabad\nNazeer Ba...  SQL Developer
# 4   b'Aradhana Tripathi\n\n\n\nCurrent Location: G...  SQL Developer
# 5   b'resume\n\n\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\tRa...  SQL Developer
# 6   b'Resume\n\nName     :  Neeraj Mishra\n\n\n\nE...  SQL Developer
# 7   b'KAMBALLA PRADEEP                            ...  SQL Developer
# 8   b'SQL DEVELOPER\n\nName: -   Bandi prem sai\n\...  SQL Developer
# 9   b'RAJU PAVANA KUMARI\n\n\n\n\t\n\n\tProfession...  SQL Developer
# 10  b"BUDDHA VAMSI                                ...  SQL Developer
# 11  b'\n\nCareer objective\n\n\nA rewarding opport...  SQL Developer
# 12  b'ANIL KUMAR MADDUKURI  \t\t\n\nSQL & MSBI Dev...  SQL Developer
# 13  b'SQL SERVER DEVELOPER\n\n\n\n\n\nP. Syam Kuma...  SQL Developer

# %%
directory = '/content/drive/MyDrive/Resumes_project/Resumes/workday resumes'
file_path4 = []
category4 = []

for i in os.listdir(directory):
    if i.endswith('.docx') or i.endswith('.doc') or i.endswith('.pdf'):
        file_path4.append(textract.process(os.path.join(directory, i)))
        category4.append('workday')

# %%
data4 = pd.DataFrame(data = file_path4 , columns = ['Raw_Details'])
data4['Category4'] = category4
data4
# Out:
#                                           Raw_Details Category4
# 0   b'\nVenkateswarlu.B                           ...   workday
# 1   b'JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SU...   workday
# 2   b'WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\...   workday
# 3   b'Chinna Subbarayudu M\n\nDOB: 06th March 1994...   workday
# 4   b'VENKATA SAIKRISHNA\n\n Workday Consultant\n\...   workday
# 5   b'\n\n                             Madeeswar A...   workday
# 6   b'Name         : Gopi Krishna Reddy\n\n\t\t\t\...   workday
# 7   b'Mooraboyina Guravaiah\n\nWorkday Integration...   workday
# 8   b'Vinay kumar .v\nWorkday Functional Consultan...   workday
# 9   b"\n                                         H...   workday
# 10  b'Srikanth (WORKDAY hCM Consultant)\t         ...   workday
# 11  b'\nShireesh                                  ...   workday
# 12  b"\n      Workday Integration Consultant\n\nNa...   workday
# 13  b'\nName  : Naresh Babu Cherukuri\n\n\nObjecti...   workday
# 14  b'\nHIMA.MENDU\n\n\n\nCareer Objective\nTo con...   workday
# 15  b"\nHarikrishna Akula\n\n\n\n Summary:\n    \x...   workday
# 16  b'Workday HCM  Techno functional Consultant   ...   workday
# 17  b'Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...   workday
# 18  b'G Himaja\n\n                                ...   workday
# 19  b"\n[pic]                                   Na...   workday
# 20  b'\n  [pic]\n  [pic]\n\n    \xe2\x80\xa2 3.3 y...   workday

# %%
# directory = '/content/drive/MyDrive/project p390/intern'
# file_path5 = []
# category5 = []

# for i in os.listdir(directory):
#     if i.endswith('.docx') or i.endswith('.doc') or i.endswith('.pdf'):
#         file_path5.append(textract.process(os.path.join(directory, i)))
#         category5.append('intern')

# %%
# data5 = pd.DataFrame(data = file_path5 , columns = ['Raw_Details'])
# data5['Category5'] = category5
# data5

# %%
resume_data = pd.concat([data1, data2, data3, data4], ignore_index=True)

# %%
resume_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Raw_Details  79 non-null     object
#  1   Category1    24 non-null     object
#  2   Category2    20 non-null     object
#  3   Category3    14 non-null     object
#  4   Category4    21 non-null     object
# dtypes: object(5)
# memory usage: 3.2+ KB

# %% [markdown]
# ##3.1 Merge all Unnecessary column in One Column

# %%
resume_data['Category'] = category1 + category2 + category3 + category4
resume_data
# Out:
#                                           Raw_Details        Category1  \
# 0   b'MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW...  React developer
# 1   b'Naveen Sadhu\n\n\n\n\n\nTitle: software deve...  React developer
# 2   b'SUSOVAN  BAG   \n\nSeeking  a  challenging  ...  React developer
# 3   b'Name: Ravali P \n\n\n\n                     ...  React developer
# 4   b'Venkatalakshmi Pedireddy\n\nSoftware Develop...  React developer
# ..                                                ...              ...
# 74  b'Workday HCM  Techno functional Consultant   ...              NaN
# 75  b'Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...              NaN
# 76  b'G Himaja\n\n                                ...              NaN
# 77  b"\n[pic]                                   Na...              NaN
# 78  b'\n  [pic]\n  [pic]\n\n    \xe2\x80\xa2 3.3 y...              NaN
#
#    Category2 Category3 Category4         Category
# 0        NaN       NaN       NaN  React developer
# 1        NaN       NaN       NaN  React developer
# 2        NaN       NaN       NaN  React developer
# 3        NaN       NaN       NaN  React developer
# 4        NaN       NaN       NaN  React developer
# ..       ...       ...       ...              ...
# 74       NaN       NaN   workday          workday
# 75       NaN       NaN   workday          workday
# 76       NaN       NaN   workday          workday
# 77       NaN       NaN   workday          workday
# 78       NaN       NaN   workday          workday
#
# [79 rows x 6 columns]

# %%
resume_data.drop(['Category1', 'Category2', 'Category3', 'Category4'], axis = 1, inplace = True)
resume_data = resume_data[["Category", "Raw_Details"]]

# %% [markdown]
# ##3.2 Final Dataset

# %%
resume_data.head(5)
# Out:
#           Category                                        Raw_Details
# 0  React developer  b'MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW...
# 1  React developer  b'Naveen Sadhu\n\n\n\n\n\nTitle: software deve...
# 2  React developer  b'SUSOVAN  BAG   \n\nSeeking  a  challenging  ...
# 3  React developer  b'Name: Ravali P \n\n\n\n                     ...
# 4  React developer  b'Venkatalakshmi Pedireddy\n\nSoftware Develop...

# %%
resume_data["Raw_Details"][4]
# Out:
# b'Venkatalakshmi Pedireddy\n\nSoftware Developer\n\nExperience 3 Years\n\n\n\n\n\n\nVisakhapatnam, India\n\n\n\n\n\n\n\n\n\nWORK EXPERIENCE\n\nDeveloper\n\nSchemax Expert Techno Crafts Pvt. Ltd\n\n\t05/2018 - Present,\tVisakapatnam\n\nAchievements/Tasks\n\nWorked on both front end and back end\n\nResponsible for development and management of the project\n\n\n\n\n\nEDUCATION\n\nSSC\n\nZ. P. G. H. School\n\n\t08/2011 - 03/2012,\t8.5 CGPA\n\n\n\n\n\nBoard Of Intermediate, AP\n\nSri Prakash Junior College\n\n\t08/2012 - 03/2014,\t81.1%\n\n\n\n\n\nB.tech\n\nSri Prakash College Of Engineering\n\n\t08/2014 - 03/2018,\t73.33%\n\n\nSKILLS\n\n\n\n\n\nHTML\n\nHTML \n\nCSS\n\nCSS \n\nJavaScript\n\nJavaScript \n\nReact Js\n\nReact Js \n\nMysql\n\nMysql\n\n\n\nNest Js\n\nNest Js\n\n\n\nPERSONAL PROJECTS\n\nPurchases Management (03/2021 - 04/2021)\n\nIt is used for tracking purchases, Pending Payments, Discounts Based on Users (Retailer/Distributor)\n\n\n\nCorona Awareness Website (03/2020 - 04/2021)\n\nTo Provide Awereness on Covid https://batvidcoronaawareness.000webhostapp.com\n\n\n\n\n\n\n\nPROJECTS\n\nMaterial Management System (08/2018 - 01/2019)\n\nMMS is tracking Procurement Material from Indents to Transfers. and to maintain stock for material of the plant - Technologies Used - YII Frame Work, Angular Js, MySql\n\n\n\nWarehouse Management System (02/2019 - 03/2019)\n\nWMS is to Maintain the stock, Sale, Purchase, Dispatch - Technologies Used - YII Frame Work, Angular Js, MySql\n\n\n\nBoard Of Intermediate Support (03/2019 - 04/2019)\n\nBOI is to support and track the Employees attendance, Payments to employees -Technologies Used Joomla Frame Work, Mysql\n\n\n\nSales (04/2019 - 08/2020)\n\nSales is to track the purchases of two wheeler, three wheeler and transfer between branches - Technologies Used- Nx Repo, React Js, Nest Js, Type ORM, Mysql, Swagger\n\n\n\nApparel Management (09/2020 - 04/2021)\n\nApparel Management Is a large Project is used to track Orders, Sewing, Cutting, Embroidery, productivity of Employees tracking for the plant Technologies Used- Nx Repo, React Js, Nest Js, Type ORM, Mysql, Swagger\n\n\n\nEnterprice resource planning (05/2021 - Present)\n\nErp is used to track the orders, Packing/RM Procurement, Production, logistics -Technologies Used- Nx Repo, React Js, Nest Js, Type ORM, Mysql, Swagger\n\n\n\n\n\n\n\nLANGUAGES\n\n\n\nTelugu\n\nNative or Bilingual Pro\xef\xac\x81ciency\n\n\nEnglish\n\nFull Professional Pro\xef\xac\x81ciency\n\n\n\n\n\n\n\n\n\nLearning New Technologies\n\nLearning New TechnologiesINTERESTS'

# %% [markdown]
# ##3.3 Save new CSV File

# %%
resume_data.to_csv('Raw_Resume.csv', index=False)

# %% [markdown]
# ##4. Data Understanding

# %%
resume_data = pd.read_csv("Raw_Resume.csv")
resume_data
# Out:
#            Category                                        Raw_Details
# 0   React developer  b'MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW...
# 1   React developer  b'Naveen Sadhu\n\n\n\n\n\nTitle: software deve...
# 2   React developer  b'SUSOVAN  BAG   \n\nSeeking  a  challenging  ...
# 3   React developer  b'Name: Ravali P \n\n\n\n                     ...
# 4   React developer  b'Venkatalakshmi Pedireddy\n\nSoftware Develop...
# ..              ...                                                ...
# 74          workday  b'Workday HCM  Techno functional Consultant   ...
# 75          workday  b'Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 76          workday  b'G Himaja\n\n                                ...
# 77          workday  b"\n[pic]                                   Na...
# 78          workday  b'\n  [pic]\n  [pic]\n\n    \xe2\x80\xa2 3.3 y...
#
# [79 rows x 2 columns]

# %%
resume_data[resume_data.Category == 'workday']
# Out:
#    Category                                        Raw_Details
# 58  workday  b'\nVenkateswarlu.B                           ...
# 59  workday  b'JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SU...
# 60  workday  b'WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\...
# 61  workday  b'Chinna Subbarayudu M\n\nDOB: 06th March 1994...
# 62  workday  b'VENKATA SAIKRISHNA\n\n Workday Consultant\n\...
# 63  workday  b'\n\n                             Madeeswar A...
# 64  workday  b'Name         : Gopi Krishna Reddy\n\n\t\t\t\...
# 65  workday  b'Mooraboyina Guravaiah\n\nWorkday Integration...
# 66  workday  b'Vinay kumar .v\nWorkday Functional Consultan...
# 67  workday  b"\n                                         H...
# 68  workday  b'Srikanth (WORKDAY hCM Consultant)\t         ...
# 69  workday  b'\nShireesh                                  ...
# 70  workday  b"\n      Workday Integration Consultant\n\nNa...
# 71  workday  b'\nName  : Naresh Babu Cherukuri\n\n\nObjecti...
# 72  workday  b'\nHIMA.MENDU\n\n\n\nCareer Objective\nTo con...
# 73  workday  b"\nHarikrishna Akula\n\n\n\n Summary:\n    \x...
# 74  workday  b'Workday HCM  Techno functional Consultant   ...
# 75  workday  b'Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 76  workday  b'G Himaja\n\n                                ...
# 77  workday  b"\n[pic]                                   Na...
# 78  workday  b'\n  [pic]\n  [pic]\n\n    \xe2\x80\xa2 3.3 y...

# %%
resume_data.isnull().sum()
# Out:
# Category       0
# Raw_Details    0
# dtype: int64

# %% [markdown]
# ##4.1 Number of Words in each Resume

# %%
resume_data['Word_Count'] = resume_data['Raw_Details'].apply(lambda x: len(str(x).split(" ")))
resume_data[['Raw_Details','Word_Count']].head()
# Out:
#                                          Raw_Details  Word_Count
# 0  b'MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW...         945
# 1  b'Naveen Sadhu\n\n\n\n\n\nTitle: software deve...         253
# 2  b'SUSOVAN  BAG   \n\nSeeking  a  challenging  ...         533
# 3  b'Name: Ravali P \n\n\n\n                     ...        1795
# 4  b'Venkatalakshmi Pedireddy\n\nSoftware Develop...         264

# %% [markdown]
# ##4.2 Number of Characters

# %%
resume_data['Char_Count'] = resume_data['Raw_Details'].str.len() ## this also includes spaces
resume_data[['Raw_Details','Char_Count']].head()
# Out:
#                                          Raw_Details  Char_Count
# 0  b'MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW...        3088
# 1  b'Naveen Sadhu\n\n\n\n\n\nTitle: software deve...        1958
# 2  b'SUSOVAN  BAG   \n\nSeeking  a  challenging  ...        2022
# 3  b'Name: Ravali P \n\n\n\n                     ...        7704
# 4  b'Venkatalakshmi Pedireddy\n\nSoftware Develop...        2574

# %% [markdown]
# ##4.3 Number of Stopwords

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)

# %%
import nltk
import pandas as pd

# Download the stopwords corpus
nltk.download('stopwords')

# Import the stopwords corpus
from nltk.corpus import stopwords

# Extract the stopwords
stop = stopwords.words('english')

# Count the number of stopwords in each resume
resume_data['Stopwords'] = resume_data['Raw_Details'].apply(lambda x: len([x for x in x.split() if x in stop]))

# Print the first few rows of the DataFrame
resume_data[['Raw_Details','Stopwords']].head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#                                          Raw_Details  Stopwords
# 0  b'MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW...         66
# 1  b'Naveen Sadhu\n\n\n\n\n\nTitle: software deve...         58
# 2  b'SUSOVAN  BAG   \n\nSeeking  a  challenging  ...         39
# 3  b'Name: Ravali P \n\n\n\n                     ...         65
# 4  b'Venkatalakshmi Pedireddy\n\nSoftware Develop...         43

# %% [markdown]
# ##4.4 Number of Numerics

# %%
resume_data['Numerics'] = resume_data['Raw_Details'].apply(lambda x: len([x for x in x.split() if x.isdigit()]))
resume_data[['Raw_Details','Numerics']].head()
# Out:
#                                          Raw_Details  Numerics
# 0  b'MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW...         2
# 1  b'Naveen Sadhu\n\n\n\n\n\nTitle: software deve...         0
# 2  b'SUSOVAN  BAG   \n\nSeeking  a  challenging  ...         0
# 3  b'Name: Ravali P \n\n\n\n                     ...         6
# 4  b'Venkatalakshmi Pedireddy\n\nSoftware Develop...         1

# %%
resume_data
# Out:
#            Category                                        Raw_Details  \
# 0   React developer  b'MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW...
# 1   React developer  b'Naveen Sadhu\n\n\n\n\n\nTitle: software deve...
# 2   React developer  b'SUSOVAN  BAG   \n\nSeeking  a  challenging  ...
# 3   React developer  b'Name: Ravali P \n\n\n\n                     ...
# 4   React developer  b'Venkatalakshmi Pedireddy\n\nSoftware Develop...
# ..              ...                                                ...
# 74          workday  b'Workday HCM  Techno functional Consultant   ...
# 75          workday  b'Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 76          workday  b'G Himaja\n\n                                ...
# 77          workday  b"\n[pic]                                   Na...
# 78          workday  b'\n  [pic]\n  [pic]\n\n    \xe2\x80\xa2 3.3 y...
#
#     Word_Count  Char_Count  Stopwords  Numerics
# 0          945        3088         66         2
# 1          253        1958         58         0
# 2          533        2022         39         0
# 3         1795        7704         65         6
# 4          264        2574         43         1
# ..         ...         ...        ...       ...
# 74        1334        9467        340         7
# 75         716        6655        153         1
# 76        1317        6154        157         2
# 77        1394        7051        167         4
# 78        1274        5856        131         3
#
# [79 rows x 6 columns]

# %% [markdown]
# ##5. Text Pre-Processing

# %% [markdown]
# ###5.1 Using Regular Expression

# %%
def preprocess(sentence):
    sentence = str(sentence)
    sentence = sentence.lower()
    sentence = sentence.replace('{html}',"")
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', sentence)
    rem_url = re.sub(r'http\S+', '',cleantext)
    rem_num = re.sub('[0-9]+', '', rem_url)
    tokenizer = RegexpTokenizer(r'\w+')
    tokens = tokenizer.tokenize(rem_num)
    filtered_words = [w for w in tokens if len(w) > 2 if not w in stopwords.words('english')]

    return " ".join(filtered_words)

# %%
# Out:
# ERROR: Could not find a version that satisfies the requirement re (from versions: none)
# ERROR: No matching distribution found for re

# %%
# Import the RegexpTokenizer class
from nltk.tokenize import RegexpTokenizer

# Read the resume data
resume_data = pd.read_csv('Raw_Resume.csv')

# Preprocess the resume details
resume_data['Resume_Details'] = resume_data.Raw_Details.apply(lambda x: preprocess(x))

# Print the preprocessed resume details
print(resume_data['Resume_Details'])
# Out:
# 0     mareedu lokesh babu nprofessional overview aro...
# 1     naveen sadhu ntitle software developer nlocati...
# 2     susovan bag nseeking challenging position fiel...
# 3     name ravali curriculum vitae specialization co...
# 4     venkatalakshmi pedireddy nsoftware developer n...
#                             ...
# 74    workday hcm techno functional consultant nrahu...
# 75    ramesh workday hcm consultant nprofessional su...
# 76    himaja ncareer objective nto work towards achi...
# 77    pic name sumanth royal nprofessional summary t...
# 78    pic pic years experience workday hcm technical...
# Name: Resume_Details, Length: 79, dtype: object

# %% [markdown]
# ###5.2 Clean Text from Resume

# %%
resume_data
# Out:
#            Category                                        Raw_Details  \
# 0   React developer  b'MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW...
# 1   React developer  b'Naveen Sadhu\n\n\n\n\n\nTitle: software deve...
# 2   React developer  b'SUSOVAN  BAG   \n\nSeeking  a  challenging  ...
# 3   React developer  b'Name: Ravali P \n\n\n\n                     ...
# 4   React developer  b'Venkatalakshmi Pedireddy\n\nSoftware Develop...
# ..              ...                                                ...
# 74          workday  b'Workday HCM  Techno functional Consultant   ...
# 75          workday  b'Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 76          workday  b'G Himaja\n\n                                ...
# 77          workday  b"\n[pic]                                   Na...
# 78          workday  b'\n  [pic]\n  [pic]\n\n    \xe2\x80\xa2 3.3 y...
#
#                                        Resume_Details
# 0   mareedu lokesh babu nprofessional overview aro...
# 1   naveen sadhu ntitle software developer nlocati...
# 2   susovan bag nseeking challenging position fiel...
# 3   name ravali curriculum vitae specialization co...
# 4   venkatalakshmi pedireddy nsoftware developer n...
# ..                                                ...
# 74  workday hcm techno functional consultant nrahu...
# 75  ramesh workday hcm consultant nprofessional su...
# 76  himaja ncareer objective nto work towards achi...
# 77  pic name sumanth royal nprofessional summary t...
# 78  pic pic years experience workday hcm technical...
#
# [79 rows x 3 columns]

# %% [markdown]
# ###5.3 Save the Clean Data in new CSV File

# %%
resume_data.drop(['Raw_Details'], axis = 1, inplace = True)
resume_data
# Out:
#            Category                                     Resume_Details
# 0   React developer  mareedu lokesh babu nprofessional overview aro...
# 1   React developer  naveen sadhu ntitle software developer nlocati...
# 2   React developer  susovan bag nseeking challenging position fiel...
# 3   React developer  name ravali curriculum vitae specialization co...
# 4   React developer  venkatalakshmi pedireddy nsoftware developer n...
# ..              ...                                                ...
# 74          workday  workday hcm techno functional consultant nrahu...
# 75          workday  ramesh workday hcm consultant nprofessional su...
# 76          workday  himaja ncareer objective nto work towards achi...
# 77          workday  pic name sumanth royal nprofessional summary t...
# 78          workday  pic pic years experience workday hcm technical...
#
# [79 rows x 2 columns]

# %%
resume_data.to_csv('Cleaned_Resumes.csv', index = False)

# %%
resume_data = pd.read_csv('Cleaned_Resumes.csv')
resume_data
# Out:
#            Category                                     Resume_Details
# 0   React developer  mareedu lokesh babu nprofessional overview aro...
# 1   React developer  naveen sadhu ntitle software developer nlocati...
# 2   React developer  susovan bag nseeking challenging position fiel...
# 3   React developer  name ravali curriculum vitae specialization co...
# 4   React developer  venkatalakshmi pedireddy nsoftware developer n...
# ..              ...                                                ...
# 74          workday  workday hcm techno functional consultant nrahu...
# 75          workday  ramesh workday hcm consultant nprofessional su...
# 76          workday  himaja ncareer objective nto work towards achi...
# 77          workday  pic name sumanth royal nprofessional summary t...
# 78          workday  pic pic years experience workday hcm technical...
#
# [79 rows x 2 columns]

# %%
resume_data.Resume_Details[4]
# Out:
# 'venkatalakshmi pedireddy nsoftware developer nexperience years nvisakhapatnam india nwork experience ndeveloper nschemax expert techno crafts pvt ltd present tvisakapatnam nachievements tasks nworked front end back end nresponsible development management project neducation nssc school cgpa nboard intermediate nsri prakash junior college tech nsri prakash college engineering nskills nhtml nhtml ncss ncss njavascript njavascript nreact nreact nmysql nmysql nnest nnest npersonal projects npurchases management nit used tracking purchases pending payments discounts based users retailer distributor ncorona awareness website nto provide awereness covid management system nmms tracking procurement material indents transfers maintain stock material plant technologies used yii frame work angular mysql nwarehouse management system nwms maintain stock sale purchase dispatch technologies used yii frame work angular mysql nboard intermediate support nboi support track employees attendance payments employees technologies used joomla frame work mysql nsales nsales track purchases two wheeler three wheeler transfer branches technologies used repo react nest type orm mysql swagger napparel management napparel management large project used track orders sewing cutting embroidery productivity employees tracking plant technologies used repo react nest type orm mysql swagger nenterprice resource planning present nerp used track orders packing procurement production logistics technologies used repo react nest type orm mysql swagger nlanguages ntelugu nnative bilingual pro xef xac xciency nenglish nfull professional pro xef xac xciency nlearning new technologies nlearning new technologiesinterests'

# %% [markdown]
# ###6. Named Entity Recognition (NER)

# %%
# !pip install nltk
import nltk
nltk.download('punkt')
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import string

oneSetOfStopWords = set(stopwords.words('english')+['``',"''"])
totalWords =[]
Sentences = resume_data['Resume_Details'].values
cleanedSentences = ""
for records in Sentences:
    cleanedText = preprocess(records)
    cleanedSentences += cleanedText
    requiredWords = nltk.word_tokenize(cleanedText)
    for word in requiredWords:
        if word not in oneSetOfStopWords and word not in string.punctuation:
            totalWords.append(word)

wordfreqdist = nltk.FreqDist(totalWords)
mostcommon = wordfreqdist.most_common(50)
print(mostcommon)
# Out:
# [('experience', 464), ('peoplesoft', 413), ('application', 395), ('using', 389), ('workday', 374), ('server', 354), ('data', 329), ('reports', 321), ('business', 267), ('sql', 267), ('process', 236), ('web', 225), ('database', 218), ('knowledge', 193), ('system', 191), ('integrations', 186), ('tools', 182), ('integration', 182), ('project', 179), ('support', 176), ('like', 175), ('hcm', 170), ('development', 160), ('skills', 157), ('services', 156), ('team', 153), ('servers', 152), ('people', 152), ('testing', 149), ('creating', 148), ('worked', 148), ('report', 147), ('various', 146), ('client', 143), ('developer', 134), ('management', 134), ('security', 133), ('issues', 132), ('working', 130), ('oracle', 130), ('eib', 130), ('production', 129), ('studio', 128), ('design', 127), ('nproject', 126), ('custom', 124), ('core', 117), ('applications', 115), ('domains', 115), ('involved', 112)]

# %% [markdown]
# ###7. Parts Of Speech (POS) Tagging

# %%
# !pip install spacy
import spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.7.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.25.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.1.1)

# %%
# !python -m spacy download en_core_web_lg
# Out:
# Collecting en-core-web-lg==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.7.1/en_core_web_lg-3.7.1-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from en-core-web-lg==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.7.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.25.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.1.1)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
nlp = spacy.load('en_core_web_lg')

one_block = cleanedSentences[1300:5200]
doc_block = nlp(one_block)
spacy.displacy.render(doc_block, style= 'ent', jupyter= True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> ndesigned website using html css nprogramming coordinating team nresponsibilities include database design code profiling extensive documentation nreview perform design validation working client nimplemented validations required fields dynamically coordinating team client
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     weekly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  status calls close follow testing team resolving issues review end user key functionalities system work improvements application technically
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ncareer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  profiles nsoftware developer
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     maganti
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  solutions
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vijayawada
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     august
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  date
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mareedu lokesh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  babu place signaturenaveen
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sadhu ntitle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  software developer nlocation
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hyderabad
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  india nprofessional summary year overall experience html
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sql reactjs nodejs nexperience working application development
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  testing tool nhard working enthusiastic texcellent communication interpersonal analytical skills strong ability perform part team nexceptional ability learn new concepts neducation tbachelor technology computer science engineering marri
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     laxman reddy institute technology management
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  affiliated
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     jntuh nskills ntechnology
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  nmern stack
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nframeworks nframework nides
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     neclipse
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  visual studio code ndatabases
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nsql mongo database
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  noperating systems nwindows unix nprofessional experience ncurrent project nclient
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     inline usa norganization edvenswa tech pvt ltd ntechnology mern
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  stack html css bootstrap ndescription nthe project goal provide whenever user wants servicing bike directly application book slot bike servicing whenever customer problem directly book service service provider take bike servicing ncontribution nunderstand implement features nnegotiate scope resolving conflicting priorities ntranslate requirements meaningful stories team deliver napplication deployment
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ndeveloped
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  optimized code per requirement npersonal details tname tnaveen
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sadhu tdob
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  taddress
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nhyderabad tlanguages
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  known
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tenglish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hindi telugu tmarital
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  status tsingle nyours sincerely
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     na

# %%
for token in doc_block[:30]:
    print(token,token.pos_)
# Out:
#   SPACE
# ndesigned PROPN
# website NOUN
# using VERB
# html PROPN
# css PROPN
# nprogramming NOUN
# coordinating VERB
# team NOUN
# nresponsibilities NOUN
# include VERB
# database NOUN
# design NOUN
# code NOUN
# profiling VERB
# extensive ADJ
# documentation NOUN
# nreview NOUN
# perform VERB
# design NOUN
# validation NOUN
# working VERB
# client NOUN
# nimplemented VERB
# validations NOUN
# required VERB
# fields NOUN
# dynamically ADV
# coordinating VERB
# team NOUN

# %% [markdown]
# ###7.1 Filtering out only the Nouns and Verbs from the Text to Tokens

# %%
one_block = cleanedSentences
doc_block = nlp(one_block)
nouns_verbs = [token.text for token in doc_block if token.pos_ in ('NOUN','VERB')]
print(nouns_verbs[:250])
# Out:
# ['overview', 'years', 'experience', 'software', 'design', 'development', 'implementation', 'maintenance', 'applications', 'using', 'react', 'object', 'oriented', 'php', 'programming', 'nknowledge', 'versioning', 'control', 'web', 'development', 'using', 'problem', 'solving', 'skills', 'presentation', 'skills', 'team', 'player', 'work', 'technology', 'affiliated', 'skills', 'technologies', 'react', 'system', 'twindows', 'studio', 'repository', 'tools', 'servers', 'concrete', 'team', 'size', 'react', 'ndescription', 'product', 'built', 'redimix', 'product', 'related', 'construction', 'industry', 'supplies', 'redimix', 'based', 'customer', 'requirement', 'take', 'orders', 'customers', 'business', 'mix', 'manages', 'sales', 'stock', 'accounting', 'shipping', 'customer', 'data', 'place', 'inventory', 'control', 'improves', 'tracking', 'control', 'inventory', 'activities', 'stock', 'movements', 'nresponsibilities', 'participation', 'development', 'delivery', 'deadlines', 'ndesigned', 'website', 'using', 'nprogramming', 'coordinating', 'team', 'nresponsibilities', 'include', 'database', 'design', 'code', 'profiling', 'documentation', 'nreview', 'perform', 'design', 'validation', 'working', 'client', 'nimplemented', 'validations', 'required', 'fields', 'coordinating', 'team', 'client', 'status', 'calls', 'follow', 'testing', 'team', 'resolving', 'issues', 'review', 'end', 'user', 'functionalities', 'system', 'work', 'improvements', 'application', 'profiles', 'nsoftware', 'developer', 'solutions', 'developer', 'nlocation', 'experience', 'working', 'application', 'development', 'testing', 'tool', 'nhard', 'working', 'communication', 'skills', 'ability', 'perform', 'part', 'team', 'ability', 'learn', 'concepts', 'tbachelor', 'technology', 'computer', 'science', 'engineering', 'affiliated', 'database', 'systems', 'nwindows', 'stack', 'project', 'goal', 'provide', 'user', 'wants', 'servicing', 'bike', 'application', 'book', 'slot', 'bike', 'servicing', 'customer', 'problem', 'book', 'service', 'service', 'provider', 'take', 'bike', 'servicing', 'ncontribution', 'features', 'scope', 'resolving', 'conflicting', 'priorities', 'ntranslate', 'requirements', 'stories', 'team', 'deliver', 'napplication', 'deployment', 'ndeveloped', 'optimized', 'code', 'requirement', 'details', 'tname', 'nhyderabad', 'tlanguages', 'known', 'bag', 'nseeking', 'challenging', 'position', 'field', 'science', 'technology', 'utilize', 'skills', 'organization', 'growth', 'enhance', 'knowledge', 'learning', 'give', 'organization', 'nskills', 'routing', 'switching', 'subnetting', 'algorithms', 'data', 'structures', 'networking', 'troubleshooting', 'skills', 'leadership', 'collaboration', 'communication', 'customer', 'handling', 'skills', 'agriculture', 'nbuilt', 'product', 'farmers', 'using', 'solution', 'technologies', 'combined', 'work', 'water', 'motor', 'controllers', 'using', 'sensors', 'management', 'purchase', 'return']

# %% [markdown]
# ###7.2 Counting all the Nouns and Verbs present in the Tokens of words

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer()
X = cv.fit_transform(nouns_verbs)
sum_words = X.sum(axis=0)

words_freq = [(word,sum_words[0,idx]) for word, idx in cv.vocabulary_.items()]
words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)

wd_df = pd.DataFrame(words_freq)
wd_df.columns = ['Words','Count']
wd_df[0:15]
# Out:
#            Words  Count
# 0    application    394
# 1          using    381
# 2     experience    380
# 3        reports    321
# 4           data    298
# 5        workday    296
# 6       business    252
# 7         server    234
# 8        process    232
# 9            web    210
# 10      database    207
# 11        system    178
# 12  integrations    178
# 13     knowledge    173
# 14   integration    172

# %% [markdown]
# ###7.3 Visualizing the Result of Top 20 Nouns and Verbs most Frequently

# %%
# Import the necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Create the bar plot
fig, axe = plt.subplots(1,1, figsize=(10,7), dpi=200)
ax = sns.barplot(x= wd_df['Count'].head(20), y= wd_df.Words.head(20), data= wd_df, ax = axe,
            label= 'Total Pofile Category : {}'.format(len(resume_data.Category.unique())))

# Set the labels and title
axe.set_xlabel('Frequency', size=16,fontweight= 'bold')
axe.set_ylabel('Words', size=16, fontweight= 'bold')

# Rotate the x-axis labels
plt.xticks(rotation = 0)

# Add the legend and title
plt.legend(loc='best', fontsize= 'x-large')
plt.title('Top 25 Most used Nouns and Verbs in Resumes', fontsize= 18, fontweight= 'bold')

# Set the tick label font sizes
rcParams = {'xtick.labelsize':'14','ytick.labelsize':'14','axes.labelsize':'16'}

# Add bar labels
for i in ax.containers:
    ax.bar_label(i,color = 'black', fontweight = 'bold', fontsize= 12)

# Update the plot parameters
plt.rcParams.update(rcParams)

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.25.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.12.0)

# %%
# !pip install nltk
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from wordcloud import WordCloud

text = " ".join(cat for cat in wd_df.Words) # Creating the text variable

word_cloud = WordCloud(width=1000, height=800, random_state=10, background_color="black",
                       colormap="Pastel1", collocations=False, stopwords=stopwords.words('english')).generate(text)

plt.figure(figsize=(10,7), dpi=800) # Display the generated Word Cloud
plt.title('Most used Nouns and Verbs in Resumes', fontsize= 15, fontweight= 'bold')
plt.imshow(word_cloud)
plt.axis("off")

plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
resume_data
# Out:
#            Category                                     Resume_Details
# 0   React developer  mareedu lokesh babu nprofessional overview aro...
# 1   React developer  naveen sadhu ntitle software developer nlocati...
# 2   React developer  susovan bag nseeking challenging position fiel...
# 3   React developer  name ravali curriculum vitae specialization co...
# 4   React developer  venkatalakshmi pedireddy nsoftware developer n...
# ..              ...                                                ...
# 74          workday  workday hcm techno functional consultant nrahu...
# 75          workday  ramesh workday hcm consultant nprofessional su...
# 76          workday  himaja ncareer objective nto work towards achi...
# 77          workday  pic name sumanth royal nprofessional summary t...
# 78          workday  pic pic years experience workday hcm technical...
#
# [79 rows x 2 columns]

# %%
 ##download the csv file resume_data

from google.colab import files
resume_data.to_csv('resume_data.csv', index=False)
files.download('resume_data.csv')
